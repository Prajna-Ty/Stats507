# %% [markdown]
# # Question 0 - GitHub Repository
#
# Create a repository Stats507 (or similar if you have one of that name already). It should be a public repository to facilitate grading.
#
# _My github repo is: https://github.com/Prajna-Ty/Stats507_
#
# * Note that all lines starting w a dollar sign are what I wrote on command line.
#
# First, change directory (cd) to ps6, the folder that includes all contents for this problem set.
#
# $ touch .gitignore
#
# $ nano .gitignore
#
# I put the following content in the gitignore file:

# %% [raw]
# # Add this file to the root of your git repo.  Name it .gitignore
# #
# # A .gitignore file will tell git which files and directories to ignore and
# # not add to version control.
#
# .DS_Store
# .idea/
# .idea/workspace.xml
# .ipynb_checkpoints
# .__pycache__

# %% [markdown]
# $ cat .gitignore _(this is a sanity check)_
#
# $ git init
#
# (Initialized empty Git repository in /Users/apple/Documents/stats507/ps6/.git/)
#
# $ git remote add origin https://github.com/Prajna-Ty/Stats507.git
#
# $ git push -u origin main
#
#
# # Question 1 - Using Git
#
# - Extract your code from PS2Q3 into
# a stand alone script or notebook and add it to the repo.
#
#
# - Create a README that
# briefly documents the purpose of the repo
# created in the warmup.
# In the README, briefly document
# the script you included for the previous part -
# state what it dose and for what purpose.
# The README should include a link to this file.
# Hint: Use a local file path for the link.
#
# $ touch README.md
#
# The edits were directly done through a web browser.
#
# - Commit the changes from the previous step
# and push them to the remote.
# Include a direct link to the commit
# from the remote’s history in your write up.
#
# Link to the commits included in both README and this doc.
# https://github.com/Prajna-Ty/Stats507/commits/main
#
# - Create a branch named “ps4”.
# Checkout that branch and edit the file from step 3
# to include “Gender” as you did for PS4 Q1.
# Commit these changes to the branch
# and create an upstream branch on GitHub to track this branch.
# Don’t delete the branch
# (at least until after the assignment is graded).
#
# $ git branch ps4
#
# $ git checkout ps4
#
# Edit the file from the previous step to include Gender.
#
# $ git status
#
# (sanity check)
#
# $ git commit -a -m "Include Gender inn PS2Q3 script"
#
# $ git push -u origin ps4
#
# - Merge the “ps4” branch into the “main” branch.
# Include a direct link to the commit from
# the remote’s history in your write up.
#
# $ git checkout main
#
# $ git merge ps4
#
# $ git commit -a -m "Merge ps4 branch into main"
#
# $ git push
#
# https://github.com/Prajna-Ty/Stats507/commit/9ebb1a2484105b03248dbd9c8cd24b3fa0ec8e89

# %% [markdown]
# # Question 2 - GitHub Collaboration
#
# Extract your notes on a Panda’s topic from PS4Q0
# to a script of their own.
# Then, collaborate to aggregate these
# into a single document for the course.
#
# - In your Stats507 repo
# make a folder called “pandas_notes”.
#
# Directly created through a web browser.
#
# - Extract your PS4Q0 topic tutorial
# and copy it into a script called “pd_topic_XYZ.py”
# replacing XYZ with your UM unique name.
# Include your name ane UM email
# on a title “slide” (markdown cell) if you don’t have one already.
# Include a link in your writeup to this file.
#
# The file is named as "pd_topic_PRAJNATY.py".
#
# Link to the file: https://github.com/Prajna-Ty/Stats507/blob/main/pandas_notes/pd_topic_PRAJNATY.py

# %% [markdown]
# - Use the fan out tree
# distributed through Canvas for this step.
# Email the person above you on the fan out tree
# to ask for a link to their Stats507 repository.
# Complete the remainder of this step after
# the person above you on the tree.
# Clone the repository of the person above you
# on the tree, create a new Python script / notebook
# that adds your topic to all topics above you.
# Name the combined script as indicated in the fan out tree.

# %% [markdown]
# # Question 3 - PS Corrections
#
# 1. Create a commit in your “Stats507” repo (from Q0)
# with the original version of your source files
# for the problem set(s) you are correcting.
#
# 1. Copy, paste, and clearly label the GSI comments
# from Canvas into your solution for this question.
# Clearly describe which comments you are making corrections for.
#
# 1. Make your corrections and commit them
# to your Stats507 repo. Include a direct link
# to the commit (showing the diff) in your submission.
# All changes should be in a single commit
# to facilitate this – you may wish to work in a branch
# if you need to make intermediate commits.
#
# Do not include the corrections in the submission –
# just link to the commit showing the corrections.

# %% [markdown]
# Corrected PS1 and PS2.
